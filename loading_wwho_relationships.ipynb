# %%
;pwd
# Out:
# '/Users/ffl/code/wikiwho-relationships'

# %%
import pandas as pd

# %%
pd.read_csv('Mainz_out.csv', delimiter='\t').
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                            Printing relationships
# revision  author                                 deleted(-)                                         revert(-)                                          reintroduced(+)                                    redeleted(+)                                       oadds total self-deleted                                       self-revert self-reintroduced                                          self-redeleted
# ...

# %%
pd.read_csv('Mainz_out_json.csv', delimiter='\t')
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                   Printing relationships
# revision  author            deleted(-)                                         revert(-)                                          reintroduced(+)                                    redeleted(+)                                       oadds total self-deleted                                       self-revert self-reintroduced                                                                      self-redeleted
# ...
